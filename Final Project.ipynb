# %% [markdown]
# # Ligand Preferences of Innate Immune Receptor RIG-I

# %% [markdown]
# #### Chen Wang
# #### Rutgers, The State University of New Jersey
# #### National Institute of Allergy and Infectious Diseases/National Institutes of Health

# %% [markdown]
# ## Biochemical Studies of RIG-I in the Presence of 5’OH, 5’ppp, Cap-0 24mer Hairpin (HP) RNAs
#
# |                     | WT              |     RIG-I   |
# | ------------------- | ----------------|-------------|
# | RNA ligand          | $K_{d,app}(nM)$ |$k_{atpase}$ ($s^{-1}$)|
# |5OH HP RNA|38.5 $\pm$ 4|49 $\pm$ 1|
# | 5ppp HP RNA         | 1.8 $\pm$ 0.9   |33 $\pm$ 0.9 |
# | Cap-0 HP RNA | 1.7 $\pm$ 0.5      |25 $\pm$ 0.4 |
#
# ### Cap-0 HP RNA shows similar binding affinity to RIG-I as compared to 5’ppp HP RNA.

# %% [markdown]
# ## Crystal Structures of RIG-I Helicase-RD with 5’OH, 5’ppp, Cap-0 24mer HP RNAs

# %%
#insert the first figure
from IPython.display import Image
Image("Picture1.png")

# %% [markdown]
# ### RIG-I Helicase-RD protein from three structures are nearly identical, indicating the presence of 5’ppp and Cap-0 does not perturb the overall structure of the Helicase-RD.

# %%
#insert figure of no interaction with m7G
from IPython.display import Image
Image("Picture3.png")

# %% [markdown]
# ### Triphosphate contacts are consistent with previous reports.
# ### No specific m7G contacts are observed.

# %% [markdown]
# ## Interaction of 2’-OH on First Nucleotide with Histidine 830 (H830)

# %%
#insert the second figure
from IPython.display import Image
Image("Picture2.png")

# %% [markdown]
# ## Biochemical Studies of WT RIG-I and H830A RIG-I with RNAs
#
# |                     | WT              |     RIG-I                     | H830A  |                    RIG-I|
# | ------------------- | ----------------|-------------|--------------------------------------------------|
# | RNA ligand          | $K_{d,app}(nM)$ |$k_{atpase}$ ($s^{-1}$)|$K_{d,app}(nM)$ |$k_{atpase}$ ($s^{-1}$)|
# | 5ppp HP RNA         | 1.8 $\pm$ 0.9   |33 $\pm$ 0.9 |1.6 $\pm$ 1.9 |34 $\pm$ 1 |
# | 5ppp 2-OMe HP RNA | 40 $\pm$ 5      |12 $\pm$ 0.4 |2.3 $\pm$ 0.7 |32 $\pm$ 0.5|
# |Cap-0 HP RNA|1.7 $\pm$ 0.5|25 $\pm$ 0.4|1.9 $\pm$ 0.5|22 $\pm$ 0.4|
# |Cap-1 HP RNA|425 $\pm$ 50|15 $\pm$ 0.7|9.5 $\pm$ 2|24 $\pm$ 0.3|
#
# ### The 2’-O-methylated 5’ppp HP RNA has a 20-fold lower binding affinity.
# ### The H830A mutation rescues the deleterious effects of 2’-O-methylation.
# ### H830 is the primary sensor of 2’-O-methylation on the first nucleotide ribose in Cap-1 RNAs.

# %% [markdown]
# ## Cell-based Reporter Signaling Assays

# %%
#IFN signal data showed in bar chart with matplotlib
import numpy as np
import matplotlib.pyplot as plt
 
#data for the chart
RNA = ['5OH dsRNA', '5ppp dsRNA', 'Cap-0 dsRNA', 'Cap-1 dsRNA', '5ovg dsRNA']
x = np.arange(len(RNA))
a = [3.9, 8.0, 8.5, 2.1, 2.05]
b = [3.8, 8.2, 11, 6.1, 2.15]
aerror = [0.2, 0.2, 0.2, 0.1, 0.15]
berror = [0.25, 1, 1, 0.8, 0.2]

#plot the data
bar_width = 0.3

plt.bar(x, a, yerr=aerror, tick_label=RNA, width=bar_width, label='WT RIG-I')
plt.bar(x + bar_width, b, yerr=berror, tick_label=RNA, width=bar_width, label='H830A RIG-I')
plt.xlabel('RNA substrates')
plt.ylabel('Relative IFN response (RLU)')
plt.title('Cell Signaling Assay')
plt.legend()
plt.show()

# %% [markdown]
# ## Summary

# %% [markdown]
# ### RIG-I recognizes Cap-0 dsRNAs as efficiently as 5′ppp dsRNAs.
# ### RIG-I accommodates the m7G cap without perturbation of the ppp moiety interactions.
# ### 2’-O-methylation on the first nucleotide of RNA 5’ end is critical for RIG-I discrimination.
# ### H830 residue is the primary sensor of 2′-O-methylation in Cap-1 dsRNA.
